# %% [markdown]
# <a href="https://colab.research.google.com/github/ReginaMoreno/TallerHC/blob/main/Clase31Oct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1) #una fila, dos columnas, primer gráfico.
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,1,1) #dos filas, una columna, primer gráfico.
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,1,2)#dos filas, una columna, segundo gráfico.
plt.plot(x,y)

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,6)
plt.plot(x,y)

plt.show()

plt.show()

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Salidas.")

#plot 2:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Entradas.")
plt.show()

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Salidas.")

#plot 2:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Entradas.")

plt.suptitle("Mi tienda.")
plt.show()

# %%
x=np.linspace(0,6*np.pi,100)
y_sen = np.sin(x)
plt.subplot(1,2,1)
plt.plot(x,y_sen,color="green")
plt.title("seno")
plt.grid(color="pink",linewidth="5",ms=20)

x=np.linspace(0,6*np.pi,100)
y_cos = np.cos(x)
plt.subplot(1,2,2)
plt.plot(x,y_cos,color="red")
plt.title("coseno")
plt.grid(color="pink",linewidth="5",ms=20)

plt.suptitle("Gráfica del seno y coseno")
plt.show()

# %%
x=np.linspace(0,6*np.pi,100)


def grafica(x):
  y_sen = np.sin(x)
  plt.subplot(1,2,1)
  plt.plot(x,y_sen,color="green")
  plt.title("seno")
  plt.grid(color="pink",linewidth="5",ms=20)
  x=np.linspace(0,6*np.pi,100)
  y_cos = np.cos(x)
  plt.subplot(1,2,2)
  plt.plot(x,y_cos,color="red")
  plt.title("coseno")
  plt.grid(color="pink",linewidth="5",ms=20)
  plt.suptitle("Gráfica del seno y coseno")
  plt.show()
  return None

grafica(x)

# %%
x=("A","B","C")
y=(3,5,1)

plt.bar(x,y)
plt.show()

# %%
edades=list(range(5,80,5))
plt.hist(edades)
plt.show()

# %%
por=[10,20,70]
clases=["A","B","C"]

plt.pie(por)
plt.show()

# %%
por=[10,20,70]
clases=["A","B","C"]

plt.pie(por,labels=clases,autopct="%0.1f%%")
plt.show()
