# %% [markdown]
# <a href="https://colab.research.google.com/github/ReginaMoreno/TallerHC/blob/main/Clase7Nov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
link="https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv"
code="?raw=true"
url=link+code
df=pd.read_csv(url,sep=",") #sep=","(separador por comas) .

# %%
df
# Out:
#                        Country        Date  No. of confirmed cases  \
# 0                       Guinea  2014-08-29                   482.0
# 1                      Nigeria  2014-08-29                    15.0
# 2                 Sierra Leone  2014-08-29                   935.0
# 3                      Liberia  2014-08-29                   322.0
# 4                       Guinea  2014-09-05                   604.0
# ...                        ...         ...                     ...
# 2479                   Liberia  2016-03-23                  3151.0
# 2480                     Italy  2016-03-23                     1.0
# 2481                   Liberia  2016-03-23                     2.0
# 2482                   Nigeria  2016-03-23                    19.0
# 2483  United States of America  2016-03-23                     4.0
#
#       No. of confirmed deaths
# 0                       287.0
# 1                         6.0
# 2                       380.0
# 3                       225.0
# ...

# %%
link="https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv"
code="?raw=true"
url=link+code
df=pd.read_csv(url,sep=",",index_col=1) #sep=","(separador por comas) #index_col=1.

# %%
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.shape #datos,columnas.
# Out:
# (2484, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2014-08-29 to 2016-03-23
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   float64
#  2   No. of confirmed deaths  1648 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 77.6+ KB

# %%
df.head()#primeros 5.
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29        Guinea                   482.0                    287.0
# 2014-08-29       Nigeria                    15.0                      6.0
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-08-29       Liberia                   322.0                    225.0
# 2014-09-05        Guinea                   604.0                    362.0

# %%
df.tail()#últimos 5.
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
df.isnull()#cuántos datos tengo, false=vacíos true=llenos.
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-09-05    False                   False                    False
# ...             ...                     ...                      ...
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
#
# [2484 rows x 3 columns]

# %%
df.isnull().sum() #espacios faltantes.
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
#Sbaer si México tiene o esta en esa base de datos.
df['Country']#Columna a la que quiero acceder.
# Out:
# Date
# 2014-08-29                      Guinea
# 2014-08-29                     Nigeria
# 2014-08-29                Sierra Leone
# 2014-08-29                     Liberia
# 2014-09-05                      Guinea
#                         ...
# 2016-03-23                     Liberia
# 2016-03-23                       Italy
# 2016-03-23                     Liberia
# 2016-03-23                     Nigeria
# 2016-03-23    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
df['Country'].isin(["Mexico"])
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
df['Country'].isin(["Mexico"]).sum()#México no está en la base de datos si la suma es 0.
# Out:
# 0

# %%
df['Country']=="Sierra Leone"
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29     True
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
SL=df[df['Country']=="Sierra Leone"]

# %%
SL
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-09-05  Sierra Leone                  1146.0                    443.0
# 2014-09-08  Sierra Leone                  1234.0                    461.0
# 2014-09-12  Sierra Leone                  1287.0                    478.0
# 2014-09-16  Sierra Leone                  1464.0                    514.0
# ...                  ...                     ...                      ...
# 2015-12-17  Sierra Leone                  8704.0                   3589.0
# 2015-12-22  Sierra Leone                  8704.0                   3589.0
# 2015-12-23  Sierra Leone                  8704.0                   3589.0
# 2015-12-29  Sierra Leone                  8704.0                   3589.0
# 2016-03-23  Sierra Leone                  8704.0                   3589.0
#
# [259 rows x 3 columns]

# %%
SL=SL.drop("Country",axis=1)#drop=Borrar la columna country.

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0

# %%
SL[15:20]
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-10-22                  3223.0                    986.0
# 2014-10-25                  3389.0                   1008.0
# 2014-10-29                  3700.0                      NaN
# 2014-10-31                  3778.0                      NaN
# 2014-11-05                  4057.0                    893.0

# %%
SL.shape#Tamano de la base=datos,columnas.
# Out:
# (259, 2)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
SL.fillna(0.0,inplace=True)#relenar con promedio, moda, mediana o 0.0 en los datos faltantes.

# %%
SL.isnull().sum()#Ya no hay datos nulos.
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# dtype: int64

# %%
SL['No. of confirmed deaths'].mean()#Promedio de muertes estimadas.
# Out:
# 3081.019305019305

# %%
SL['No. of confirmed cases'].mean()#Promedio de casos confirmados.
# Out:
# 7883.671814671815

# %%
Dates=SL.index[0:-1:10]
NCC=SL['No. of confirmed cases'][0:-1:10]
NCD=SL['No. of confirmed deaths'][0:-1:10]

# %%
plt.plot(Dates,NCC,"o--r",ms=2,label="Infectados")
plt.plot(Dates,NCD,"o-k",ms=2,label="Decesos")
plt.grid(color="pink",linewidth="2",ms=20)
plt.title("Avance del ébola en Sierra Leona")
plt.ylabel("Casos confirmados")
plt.xlabel("Periodo de tiempo")
plt.xticks(rotation=90,fontsize=7)#Fechas rotadas y tamaño de las fechas.
plt.legend()
plt.show()

# %%
PIvsD=100*SL['No. of confirmed deaths']/SL['No. of confirmed cases']#Porcentaje de Infectados vs Decesos
SL["PIvsD"]=PIvsD

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290

# %%
#Porcentaje de los recuperados
recuperados=((100-PIvsD)/100)*SL['No. of confirmed cases']
SL["recuperados"]=recuperados

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD  \
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290
#
#             recuperados
# Date
# 2014-08-29        555.0
# 2014-09-05        703.0
# 2014-09-08        773.0
# 2014-09-12        809.0
# 2014-09-16        950.0
